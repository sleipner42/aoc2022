# %%
# %%timeit

with open('data.txt') as file:
    data = file.read().splitlines()

h = [0,0]
t = [0,0]

vectors = {
    'R':(0,1),
    'L':(0,-1),
    'U': (1,1),
    'D':(1,-1)    
}

total_pos = []

def sign(x):
    return int(x/abs(x))

def update_t_post(h, t):
    x_diff = h[0] - t[0]
    y_diff = h[1] - t[1]

    if abs(x_diff) > 1 and y_diff == 0:
        t[0]+=sign(x_diff)
    elif abs(y_diff) > 1 and x_diff == 0:
        t[1]+=sign(y_diff)
    elif abs(x_diff) > 1 or abs(y_diff) > 1: 
        t[0]+=sign(x_diff)
        t[1]+=sign(y_diff)


for line in data:
    d, s = line.split()
    s = int(s)

    dim, scale = vectors[d]

    for step in range(s):

        h[dim]+=scale

        update_t_post(h, t)
    
        total_pos.append(tuple(t))
        
print(len(set(total_pos)))

h = [0,0]
tails = [[0,0] for _ in range(9)]

total_pos = []

for line in data:
    d, s = line.split()
    s = int(s)

    dim, scale = vectors[d]

    for step in range(s):

        h[dim]+=scale

        update_t_post(h, tails[0])

        for n in range(1,9):
            update_t_post(tails[n-1], tails[n])
    
        total_pos.append(tuple(tails[-1]))
        
print(len(set(total_pos)))
# Out:
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 6494
# 2691
# 39.5 ms ± 211 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
